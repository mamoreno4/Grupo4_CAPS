# %%
import pandas as pd
import gurobipy
import os
from gurobipy import GRB, Model, quicksum
import itertools

# %%
os.chdir("C:\\Users\\julio\\OneDrive\\Escritorio\\G4 Capstone")

# %%
datos1 = pd.read_excel('Datos base G4.xlsx', sheet_name='Datos base G4')
nancagua = pd.read_excel('Datos base G4.xlsx', sheet_name='Bodega Nancagua')
machali = pd.read_excel('Datos base G4.xlsx', sheet_name='Bodega Machali')
chepica = pd.read_excel('Datos base G4.xlsx', sheet_name='Bodega Chepica')
transporte = pd.read_excel('Datos base G4.xlsx', sheet_name='Transporte')

# %%
costo_transporte = {}
for Cuartel, Machali, Chepica, Nancagua in zip(transporte['Cuartel'], transporte['Machali'], transporte['Chepica'], transporte['Nancagua']):
    costo_transporte[f'cuartel_{Cuartel}'] = {'Machali': Machali, 'Chepica': Chepica, 'Nancagua': Nancagua}

# %%
# Conjunto de cuarteles.
cuarteles = []
for i in range (1, 61):
    cuarteles.append(f'cuartel_{i}')

# Diccionario con el factor de conversion de toneladas a litros de cada cuartel.
conversion = {}

# Factor de penalización según día de cosecha.
penalizacion = {}

# %%
# Subconjuntos cepa-calidad. Cada subconjunto contiene los cuarteles que producen una cepa y calidad específica
G_variedad = []
G_reserva = []
G_premium = []
Ch_variedad = []
Ch_reserva = []
Ch_premium = []
SB_variedad = []
SB_reserva = []
SB_premium = []
C_variedad = []
C_reserva = []
C_premium = []
CS_variedad = []
CS_reserva = []
CS_premium = []
S_variedad = []
S_reserva = []
S_premium = []
M_variedad = []
M_reserva = []
M_premium = []
CF_variedad = []
CF_reserva = []
CF_premium = []
V_variedad = []
V_reserva = []
V_premium = []

# %%
# Parámetro binario que es 1 si se puede cosechar el cuartel i en el día t y 0 en caso contrario.
posible_cosechar = {}

# Total a cosechar en cada cuartel, con enfoque robusto da la misma cantidad para todos los cuarteles> 72,2 toneladas.
total_cosechar = {}

# Calidad de uva en el cuartel j.
productividad_cuartel = {}

# Precio de venta por cuartel
precio_venta = {}

# %%
for ID, Precio, Factor, Variedad, Dia_inicial, Dia_final in zip(datos1['ID'], datos1['Precio'], datos1['Factor'], datos1['Variedad'], datos1['Dia_inicial'], datos1['Dia_final']):
    total_cosechar[f'cuartel_{int(ID)}'] = 72.2
    precio_venta[f'cuartel_{ID}'] = Precio
    if Precio == 1000:
        productividad_cuartel[f'cuartel_{int(ID)}'] = 0.5
    elif Precio == 3000:
        productividad_cuartel[f'cuartel_{int(ID)}'] = 0.42
    elif Precio == 6000:
        productividad_cuartel[f'cuartel_{int(ID)}'] = 0.3

    conversion[f'cuartel_{int(ID)}'] = Factor
    
    penal = {}
    cosechar = {}
    for i in range(0, Dia_inicial + 1):
        if i+1 < Dia_inicial:
            penal[f'dia_{i+1}'] = 0
            cosechar[f'dia_{i+1}'] = 0

        elif i+1 == Dia_inicial:
            cosechar[f'dia_{i+1}'] = 1
            cosechar[f'dia_{i+2}'] = 1
            cosechar[f'dia_{i+3}'] = 1
            cosechar[f'dia_{i+4}'] = 1
            cosechar[f'dia_{i+5}'] = 1
            cosechar[f'dia_{i+6}'] = 1
            cosechar[f'dia_{i+7}'] = 1
            cosechar[f'dia_{i+8}'] = 1

            if Precio == 1000:
                penal[f'dia_{i+1}'] = 0.8
                penal[f'dia_{i+2}'] = 0.8875
                penal[f'dia_{i+3}'] = 0.95
                penal[f'dia_{i+4}'] = 0.9875
                penal[f'dia_{i+5}'] = 1
                penal[f'dia_{i+6}'] = 0.9833
                penal[f'dia_{i+7}'] = 0.9333
                penal[f'dia_{i+8}'] = 0.85
            elif Precio == 3000:
                penal[f'dia_{i+1}'] = 0.6
                penal[f'dia_{i+2}'] = 0.775
                penal[f'dia_{i+3}'] = 0.9
                penal[f'dia_{i+4}'] = 0.975
                penal[f'dia_{i+5}'] = 1
                penal[f'dia_{i+6}'] = 0.9667
                penal[f'dia_{i+7}'] = 0.8667
                penal[f'dia_{i+8}'] = 0.7
            else:
                penal[f'dia_{i+1}'] = 0.1
                penal[f'dia_{i+2}'] = 0.4938
                penal[f'dia_{i+3}'] = 0.775
                penal[f'dia_{i+4}'] = 0.9438
                penal[f'dia_{i+5}'] = 1
                penal[f'dia_{i+6}'] = 0.9111
                penal[f'dia_{i+7}'] = 0.6444
                penal[f'dia_{i+8}'] = 0.2
            
            for j in range(0, datos1['Dia_final'].max() - len(cosechar)):
                penal[f'dia_{i + j + 9}'] = 0
                cosechar[f'dia_{i + j + 9}'] = 0

        penalizacion[f'cuartel_{int(ID)}'] = penal
        posible_cosechar[f'cuartel_{int(ID)}'] = cosechar

    if Variedad == 'G':
        if Precio == 1000:
            G_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            G_reserva.append(f'cuartel_{int(ID)}')
        else:
            G_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'Ch':
        if Precio == 1000:
            Ch_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            Ch_reserva.append(f'cuartel_{int(ID)}')
        else:
            Ch_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'SB':
        if Precio == 1000:
            SB_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            SB_reserva.append(f'cuartel_{int(ID)}')
        else:
            SB_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'C':
        if Precio == 1000:
            C_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            C_reserva.append(f'cuartel_{int(ID)}')
        else:
            C_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'CS':
        if Precio == 1000:
            CS_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            CS_reserva.append(f'cuartel_{int(ID)}')
        else:
            CS_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'S':
        if Precio == 1000:
            S_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            S_reserva.append(f'cuartel_{int(ID)}')
        else:
            S_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'M':
        if Precio == 1000:
            M_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            M_reserva.append(f'cuartel_{int(ID)}')
        else:
            M_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'CF':
        if Precio == 1000:
            CF_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            CF_reserva.append(f'cuartel_{int(ID)}')
        else:
            CF_premium.append(f'cuartel_{int(ID)}')
    elif Variedad == 'V':
        if Precio == 1000:
            V_variedad.append(f'cuartel_{int(ID)}')
        elif Precio == 3000:
            V_reserva.append(f'cuartel_{int(ID)}')
        else:
            V_premium.append(f'cuartel_{int(ID)}')

# %%
# Grupos de cuarteles.
grupos = ['grupo_1', 'grupo_2', 'grupo_3', 'grupo_4', 'grupo_5']
trabajadores_grupo = {'grupo_1': 100, 'grupo_2': 50, 'grupo_3': 100, 'grupo_4': 50, 'grupo_5': 100}
jornada = 8
grupo_cuarteles = {}
grupo1 = []
grupo2 = []
grupo3 = []
grupo4 = []
grupo5 = []
for i in range (0,60):
    if i+1 <= 16:
        grupo1.append(f'cuartel_{i+1}')
    elif i+1 <= 22:
        grupo2.append(f'cuartel_{i+1}')
    elif i+1 <= 32:
        grupo3.append(f'cuartel_{i+1}')
    elif i+1 <= 37:
        grupo4.append(f'cuartel_{i+1}')
    elif i+1 <= 60:
        grupo5.append(f'cuartel_{i+1}')

grupo_cuarteles['grupo_1'] = grupo1
grupo_cuarteles['grupo_2'] = grupo2
grupo_cuarteles['grupo_3'] = grupo3
grupo_cuarteles['grupo_4'] = grupo4
grupo_cuarteles['grupo_5'] = grupo5

# %%
cepa_calidad = {'G':{1000:G_variedad, 3000:G_reserva, 6000:G_premium},
                'Ch': {1000:Ch_variedad, 3000:Ch_reserva, 6000:Ch_premium},
                'SB': {1000:SB_variedad, 3000:SB_reserva, 6000:SB_premium},
                'C': {1000:C_variedad, 3000:C_reserva, 6000:C_premium},
                'CS': {1000:CS_variedad, 3000:CS_reserva, 6000:CS_premium},
                'S': {1000:S_variedad, 3000:S_reserva, 6000:S_premium},
                'M': {1000:M_variedad, 3000:M_reserva, 6000:M_premium},
                'CF': {1000:CF_variedad, 3000:CF_reserva, 6000:CF_premium},
                'V': {1000:V_variedad, 3000:V_reserva, 6000:V_premium}}

# %%
# Lista de todas las cepas que se producen en la viña
cepas = ["G", "Ch", "SB", "C", "CS", "S", "M", "CF", "V"]

# Lista de todas las bodegas donde se envían las uvas cosechadas
bodegas = ["Machali", "Chepica", "Nancagua"]

# Lista de todos los días del periodo de cosecha, hasta el mayor día final de cosecha.
periodo = []
for i in range(0, datos1['Dia_final'].max()):
    periodo.append(f'dia_{i+1}')

# Lista que agrupa los días en intervalos de X cantidad de días.
indice_periodo = 12
dias_agrupados = {}
agrupacion = []
for i in range(0, datos1['Dia_final'].max() - indice_periodo + 1):
    d_a = []
    agrupacion.append(f'agrupacion_{i+1}')
    for j in range(0, indice_periodo):
        d_a.append(f'dia_{i+j+1}')
    dias_agrupados[f'agrupacion_{i+1}'] = d_a

# Lista de todas las calidades de uva que se pueden cosechar
calidades = [1000, 3000, 6000]

# Costo por hora trabajada de cada trabajador.
costo_trabajador = 12000

# Big M
M = 1000000

# Multiplicador costo perdida
multiplicador_perdida = 10

# Llenado maximo y minimo de cada estanque
llenado_maximo = 0.95
llenado_minimo = 0.75

# Cantidad de estanques en cada bodega
nro_estanques = {'Machali': 14, 'Chepica': 9, 'Nancagua': 13}

# %%
valores = []
for tanques in machali["capacidad tanques (miles de litros)"]:
    valores.append(tanques)
valores.sort()
combinaciones = []

for i in range(1, len(valores)+1):
    for c in itertools.combinations(valores, i):
        if sum(c)*llenado_minimo < 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones:
                combinaciones.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])
        elif sum(c)*llenado_minimo >= 324.9 and sum(c)*llenado_maximo <= 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones:
                combinaciones.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])

# %%
valores1 = []
for tanques in nancagua["capacidad tanques (miles de litros)"]:
    valores1.append(tanques)
valores1.sort()
combinaciones1 = []

for i in range(1, len(valores1)+1):
    for c in itertools.combinations(valores1, i):
        if sum(c)*llenado_minimo < 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones1:
                combinaciones1.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])
        elif sum(c)*llenado_minimo >= 324.9 and sum(c)*llenado_maximo <= 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones1:
                combinaciones1.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])

# %%
valores2 = []
for tanques in chepica["capacidad tanques (miles de litros)"]:
    valores2.append(tanques)
valores2.sort()
combinaciones2 = []

for i in range(1, len(valores2)+1):
    for c in itertools.combinations(valores2, i):
        if sum(c)*llenado_minimo < 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones2:
                combinaciones2.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])
        elif sum(c)*llenado_minimo >= 324.9 and sum(c)*llenado_maximo <= 324.9:
            if [sum(c)*llenado_minimo, sum(c)*llenado_maximo] not in combinaciones2:
                combinaciones2.append([sum(c)*llenado_minimo, sum(c)*llenado_maximo])

# %%
bodega_combinacion = {}

combinaciones_machali = {}
for i in range(0, len(combinaciones)):
    combinaciones_machali[f'Combinacion_{i+1}'] = combinaciones[i]

combinaciones_nancagua = {}
for i in range(len(combinaciones), len(combinaciones) + len(combinaciones1)):
    combinaciones_nancagua[f'Combinacion_{i+1}'] = combinaciones1[i - len(combinaciones)]

combinaciones_chepica = {}
for i in range(len(combinaciones) + len(combinaciones1), len(combinaciones) + len(combinaciones1) + len(combinaciones2)):
    combinaciones_chepica[f'Combinacion_{i+1}'] = combinaciones2[i - len(combinaciones) - len(combinaciones1)]

bodega_combinacion['Machali'] = combinaciones_machali
bodega_combinacion['Nancagua'] = combinaciones_nancagua
bodega_combinacion['Chepica'] = combinaciones_chepica

dic_combinaciones = {}
lista_combinaciones_machali = []
for key in combinaciones_machali.keys():
    lista_combinaciones_machali.append(key)
dic_combinaciones['Machali'] = lista_combinaciones_machali

lista_combinaciones_nancagua = []
for key in combinaciones_nancagua.keys():
    lista_combinaciones_nancagua.append(key)
dic_combinaciones['Nancagua'] = lista_combinaciones_nancagua

lista_combinaciones_chepica = []
for key in combinaciones_chepica.keys():
    lista_combinaciones_chepica.append(key)
dic_combinaciones['Chepica'] = lista_combinaciones_chepica

# %%
todas_combinaciones = []
todas_combinaciones.extend(lista_combinaciones_machali)
todas_combinaciones.extend(lista_combinaciones_nancagua)
todas_combinaciones.extend(lista_combinaciones_chepica)

# %%
lista_estanques = []
lista_estanques_machali = []
lista_estanques_nancagua = []
lista_estanques_chepica = []
dic_estanques = {}
estanques = {}
estanques_nancagua = {}
estanques_machali = {}
estanques_chepica = {}
for ID, capacidad in zip(machali['Id'], machali['capacidad tanques (miles de litros)']):
    estanques_machali[f'estanque_machali_{ID}'] = capacidad
    lista_estanques.append(f'estanque_machali_{ID}')
    lista_estanques_machali.append(f'estanque_machali_{ID}')
dic_estanques['Machali'] = lista_estanques_machali
estanques['Machali'] = estanques_machali

for ID, capacidad in zip(nancagua['Id'], nancagua['capacidad tanques (miles de litros)']):
    estanques_nancagua[f'estanque_nancagua_{ID}'] = capacidad
    lista_estanques.append(f'estanque_nancagua_{ID}')
    lista_estanques_nancagua.append(f'estanque_nancagua_{ID}')
dic_estanques['Nancagua'] = lista_estanques_nancagua
estanques['Nancagua'] = estanques_nancagua

for ID, capacidad in zip(chepica['Id'], chepica['capacidad tanques (miles de litros)']):
    estanques_chepica[f'estanque_chepica_{ID}'] = capacidad
    lista_estanques.append(f'estanque_chepica_{ID}')
    lista_estanques_chepica.append(f'estanque_chepica_{ID}')
dic_estanques['Chepica'] = lista_estanques_chepica
estanques['Chepica'] = estanques_chepica

# %%
capacidad_maxima = {'Nancagua': nancagua['capacidad tanques (miles de litros)'].sum()*llenado_maximo, 'Chepica': chepica['capacidad tanques (miles de litros)'].sum()*llenado_maximo, 'Machali': machali['capacidad tanques (miles de litros)'].sum()*llenado_maximo}
capacidad_minima = {'Nancagua': min(nancagua['capacidad tanques (miles de litros)'])*llenado_minimo, 'Chepica': min(chepica['capacidad tanques (miles de litros)'])*llenado_minimo, 'Machali': min(machali['capacidad tanques (miles de litros)'])*llenado_minimo}

# %%
# Se setea una demanda para poder trabajar con el modelo cuando se itere con la simulacion

demanda = {'G': {1000: len(cepa_calidad['G'][1000])*72.2/20, 3000: len(cepa_calidad['G'][3000])*72.2/20, 6000: len(cepa_calidad['G'][6000])*72.2/20},
           'Ch': {1000: len(cepa_calidad['Ch'][1000])*72.2/20, 3000: len(cepa_calidad['Ch'][3000])*72.2/20, 6000: len(cepa_calidad['Ch'][6000])*72.2/20},
           'SB': {1000: len(cepa_calidad['SB'][1000])*72.2/20, 3000: len(cepa_calidad['SB'][3000])*72.2/20, 6000: len(cepa_calidad['SB'][6000])*72.2/20},
           'C': {1000: len(cepa_calidad['C'][1000])*72.2/20, 3000: len(cepa_calidad['C'][3000])*72.2/20, 6000: len(cepa_calidad['C'][6000])*72.2/20},
           'CS': {1000: len(cepa_calidad['CS'][1000])*72.2/20, 3000: len(cepa_calidad['CS'][3000])*72.2/20, 6000: len(cepa_calidad['CS'][6000])*72.2/20},
           'S': {1000: len(cepa_calidad['S'][1000])*72.2/20, 3000: len(cepa_calidad['S'][3000])*72.2/20, 6000: len(cepa_calidad['S'][6000])*72.2/20},
           'M': {1000: len(cepa_calidad['M'][1000])*72.2/20, 3000: len(cepa_calidad['M'][3000])*72.2/20, 6000: len(cepa_calidad['M'][6000])*72.2/20},
           'CF': {1000: len(cepa_calidad['CF'][1000])*72.2/20, 3000: len(cepa_calidad['CF'][3000])*72.2/20, 6000: len(cepa_calidad['CF'][6000])*72.2/20},
           'V': {1000: len(cepa_calidad['V'][1000])*72.2/20, 3000: len(cepa_calidad['V'][3000])*72.2/20, 6000: len(cepa_calidad['V'][6000])*72.2/20}}

# %%
model = Model("Cosecha Vino")

# %%
# VARIABLES

# Variable binaria que indica si se cosecha o no en el cuartel j en el día t.
#V_jt = model.addVars(cuarteles, periodo, vtype=GRB.BINARY, name="V_jt")

# Variable que indica si la bodega b recibe uvas del cuartel j en el día t.
#R_jt = model.addVars(bodegas, cuarteles, periodo, vtype=GRB.BINARY, name="R_bjt")

# Variable que indica si la bodega b recibe uvas de la cepa c y calidad k en el día t.
R_btck = model.addVars(bodegas, periodo, cepas, calidades, vtype=GRB.BINARY, name="R_btck")

# Variable que indica la cantidad de uvas cosechadas en el periodo t, que son llevadas desde el cuartel j a la bodega b.
X_bjt = model.addVars(bodegas, cuarteles, periodo, vtype=GRB.CONTINUOUS, name="X_bjt")

# Variable que indica en que estanque se almacenan las uvas que llegan a cada bodega.

Y_btcke = model.addVars(bodegas, periodo, cepas, calidades, lista_estanques, vtype=GRB.BINARY, name="Y_btcke")

# Variable que indica la cantidad de trabajadores contratados en el periodo t.
#NC_t = model.addVars(periodo, vtype=GRB.CONTINUOUS, name="NC_t")

# Variable que indica la horas/hombre asignadas al cuartel j en el periodo t.
N_jt = model.addVars(cuarteles, periodo, vtype=GRB.CONTINUOUS, name="N_jt")

# %%
# Restriccion 1: No se puede enviar a una bodega en un periodo mas que la capacidad total de los estanques de fermentación.

#model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cuarteles) <= capacidad_maxima[b]*0.08 for b in bodegas for t in periodo);

# %%
# Restriccion 1: En un periodo de X días no se puede cosechar y enviar a una bodega más que la capacidad total de los estanques de fermentación de dicha bodega.

model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cuarteles for t in dias_agrupados[a]) <= capacidad_maxima[b] for b in bodegas for a in agrupacion);

# Restriccion 1: En un periodo de X días no se puede cosechar más que la capacidad total de las bodegas.

#model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cuarteles for t in dias_agrupados[a] for b in bodegas) <= quicksum(capacidad_maxima[b] for b in bodegas) for a in agrupacion);

# %%
#Restriccion X: La cantidad de estanques utilizados en un periodo de X dias no puede superar el numero de estanques de la bodega

model.addConstrs(quicksum(Y_btcke[b,t,c,k,e] for t in dias_agrupados[a] for c in cepas for k in calidades for e in dic_estanques[b]) <=  nro_estanques[b] for b in bodegas for a in agrupacion);

# %%
#Restriccion X: Un estanque no puede usarse dos veces en al menos X cantidad de dias

model.addConstrs(quicksum(Y_btcke[b,t,c,k,e] for t in dias_agrupados[a] for c in cepas for k in calidades) <= 1 for b in bodegas for e in dic_estanques[b] for a in agrupacion);

# %%
# Restriccion X: Lo que se envia a las bodegas debe poder alamcenarse en su totalidad en alguna combinación de estanques.

#model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cepa_calidad[c][k]) >= quicksum(Y_btcke[b,t,c,k,e]*bodega_combinacion[b][e][0] for e in dic_combinaciones[b]) for b in bodegas for t in periodo for c in cepas for k in calidades);

#model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cepa_calidad[c][k]) <= quicksum(Y_btcke[b,t,c,k,e]*bodega_combinacion[b][e][1] for e in dic_combinaciones[b]) for b in bodegas for t in periodo for c in cepas for k in calidades);

#model.addConstrs(quicksum(Y_btcke[b,t,c,k,e] for c in cepas for k in calidades for e in dic_combinaciones[b]) <= 1 for b in bodegas for t in periodo);

# %%
# Restriccion X: Lo que se envia a las bodegas debe poder alamcenarse en su totalidad en alguna combinación de estanques.

model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cepa_calidad[c][k]) >= quicksum(Y_btcke[b,t,c,k,e]*estanques[b][e] for e in dic_estanques[b])*llenado_minimo for b in bodegas for t in periodo for c in cepas for k in calidades);
model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cepa_calidad[c][k]) <= quicksum(Y_btcke[b,t,c,k,e]*estanques[b][e] for e in dic_estanques[b])*llenado_maximo for b in bodegas for t in periodo for c in cepas for k in calidades);

# %%
#Restriccion 2: No se puede cosechar mas que el total disponible en cada cuartel.

model.addConstrs(quicksum(X_bjt[b,j,t] for b in bodegas for t in periodo) <= total_cosechar[j] for j in cuarteles);

# %%
# Restriccion 3: La cantidad cosechada debe abastecer la demanda

model.addConstrs(quicksum(X_bjt[b,j,t] for b in bodegas for t in periodo for j in cepa_calidad[c][k]) >= demanda[c][k] for c in cepas for k in calidades);

# %%
# Restriccion 4: La cantidad cosechada debe ser mayor que el mínimo de cada bodega

model.addConstrs(quicksum(X_bjt[b,j,t]*conversion[j] for j in cepa_calidad[c][k]) >= capacidad_minima[b]*R_btck[b,t,c,k] for b in bodegas for t in periodo for c in cepas for k in calidades);

# %%
# Restriccion auxiliar para ajustar el valor de la variable binaria R_btck

model.addConstrs(R_btck[b,t,c,k]*M >= quicksum(X_bjt[b,j,t] for j in cepa_calidad[c][k]) for b in bodegas for t in periodo for c in cepas for k in calidades);

# %%
# Restriccion 5: Solo se asigna una bodega si se ha cosechado el cuartel.

#model.addConstrs(quicksum(R_bt[b,t] for b in bodegas) <= M*V_jt[j,t] for j in cuarteles for t in periodo);

# %%
# Restriccion 6: Solo se asigna una bodega si se ha cosechado

#model.addConstrs(V_jt[j,t] <= quicksum(R_bt[b,t] for b in bodegas) for j in cuarteles for t in periodo);

# %%
# Restriccion 8: Solo se cosecha el cuartel si es apto segun la ventana de cosecha.

model.addConstrs(quicksum(X_bjt[b,j,t] for b in bodegas) <= M*posible_cosechar[j][t] for j in cuarteles for t in periodo);

# %%
# Restriccion 9: La cantidad de horas/hombre asignadas por grupo de cuarteles no puede superar la cantidad maxima disponible.

model.addConstrs(quicksum(N_jt[j,t] for j in grupo_cuarteles[g]) <= trabajadores_grupo[g]*jornada for g in grupos for t in periodo);

# %%
# Restriccion 10: La cosecha debe ser igual a la productividad de los trabajadores 

model.addConstrs(quicksum(X_bjt[b,j,t] for b in bodegas) == N_jt[j,t]*productividad_cuartel[j] for j in cuarteles for t in periodo);

# %%
# Funcion objetivo

obj = quicksum(X_bjt[b,j,t]*conversion[j]*1000*precio_venta[j]*penalizacion[j][t] for b in bodegas for j in cuarteles for t in periodo) - quicksum((total_cosechar[j] - quicksum(X_bjt[b,j,t] for b in bodegas for t in periodo))*precio_venta[j]*conversion[j]*1000*multiplicador_perdida for j in cuarteles) - quicksum(N_jt[j,t]*costo_trabajador for j in cuarteles for t in periodo) - quicksum(X_bjt[b,j,t]*costo_transporte[j][b]*1000 for b in bodegas for t in periodo for j in cuarteles)

# %%
model.setObjective(obj, GRB.MAXIMIZE)

# %%
model.optimize()
# Out:
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: AMD Ryzen 7 5800H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 38414 rows, 255723 columns and 2022798 nonzeros
# Model fingerprint: 0xeb8cabbb
# Variable types: 18960 continuous, 236763 integer (236763 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 1e+06]
#   Objective range  [1e+04, 6e+07]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Found heuristic solution: objective -8.56411e+10
# Presolve removed 32267 rows and 244324 columns
# Presolve time: 1.08s
# Presolved: 6147 rows, 11399 columns, 140607 nonzeros
# Variable types: 1446 continuous, 9953 integer (9953 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
# Extra simplex iterations after uncrush: 2
#
# Root relaxation: objective 1.040549e+10, 806 iterations, 0.10 seconds (0.09 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.0405e+10    0   31 -8.564e+10 1.0405e+10   112%     -    1s
# H    0     0                    -7.71866e+09 1.0405e+10   235%     -    1s
# H    0     0                    6.232382e+09 1.0405e+10  67.0%     -    1s
# H    0     0                    9.539413e+09 1.0405e+10  9.08%     -    1s
# H    0     0                    1.004555e+10 1.0405e+10  3.58%     -    1s
# H    0     0                    1.004675e+10 1.0405e+10  3.57%     -    1s
#      0     0 1.0405e+10    0  115 1.0047e+10 1.0405e+10  3.57%     -    2s
# H    0     0                    1.031060e+10 1.0405e+10  0.92%     -    2s
# H    0     0                    1.032358e+10 1.0404e+10  0.78%     -    2s
#      0     0 1.0404e+10    0   63 1.0324e+10 1.0404e+10  0.78%     -    2s
#      0     0 1.0404e+10    0   76 1.0324e+10 1.0404e+10  0.78%     -    2s
#      0     0 1.0404e+10    0  142 1.0324e+10 1.0404e+10  0.77%     -    2s
# H    0     0                    1.035403e+10 1.0404e+10  0.48%     -    2s
#      0     0 1.0404e+10    0   65 1.0354e+10 1.0404e+10  0.48%     -    2s
#      0     0 1.0404e+10    0   67 1.0354e+10 1.0404e+10  0.48%     -    2s
#      0     0 1.0404e+10    0   69 1.0354e+10 1.0404e+10  0.48%     -    2s
#      0     0 1.0402e+10    0  136 1.0354e+10 1.0402e+10  0.46%     -    2s
#      0     0 1.0402e+10    0  141 1.0354e+10 1.0402e+10  0.46%     -    2s
#      0     0 1.0402e+10    0  136 1.0354e+10 1.0402e+10  0.46%     -    3s
#      0     0 1.0402e+10    0  137 1.0354e+10 1.0402e+10  0.46%     -    3s
#      0     0 1.0402e+10    0  133 1.0354e+10 1.0402e+10  0.46%     -    3s
#      0     0 1.0401e+10    0  155 1.0354e+10 1.0401e+10  0.46%     -    3s
# H    0     0                    1.035698e+10 1.0401e+10  0.42%     -    3s
#      0     0 1.0401e+10    0  178 1.0357e+10 1.0401e+10  0.42%     -    3s
#      0     0 1.0401e+10    0  143 1.0357e+10 1.0401e+10  0.42%     -    3s
#      0     0 1.0401e+10    0  145 1.0357e+10 1.0401e+10  0.42%     -    3s
#      0     0 1.0401e+10    0  144 1.0357e+10 1.0401e+10  0.42%     -    3s
# H    0     0                    1.036381e+10 1.0401e+10  0.36%     -    3s
# H    0     0                    1.037023e+10 1.0401e+10  0.29%     -    3s
#      0     0 1.0400e+10    0  198 1.0370e+10 1.0400e+10  0.29%     -    3s
#      0     0 1.0400e+10    0   31 1.0370e+10 1.0400e+10  0.29%     -    4s
# H    0     0                    1.037025e+10 1.0400e+10  0.29%     -    4s
#      0     0 1.0400e+10    0   88 1.0370e+10 1.0400e+10  0.29%     -    4s
#      0     0 1.0400e+10    0  141 1.0370e+10 1.0400e+10  0.29%     -    4s
#      0     0 1.0400e+10    0  191 1.0370e+10 1.0400e+10  0.29%     -    4s
# H    0     0                    1.037082e+10 1.0400e+10  0.28%     -    4s
#      0     0 1.0400e+10    0  175 1.0371e+10 1.0400e+10  0.28%     -    4s
#      0     0 1.0400e+10    0  186 1.0371e+10 1.0400e+10  0.28%     -    4s
#      0     0 1.0400e+10    0  185 1.0371e+10 1.0400e+10  0.28%     -    4s
#      0     0 1.0400e+10    0  187 1.0371e+10 1.0400e+10  0.28%     -    4s
#      0     0 1.0400e+10    0  188 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0400e+10    0  184 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0400e+10    0  196 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0400e+10    0  195 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0400e+10    0  194 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0400e+10    0  192 1.0371e+10 1.0400e+10  0.28%     -    5s
#      0     0 1.0399e+10    0  208 1.0371e+10 1.0399e+10  0.28%     -    5s
#      0     0 1.0399e+10    0  216 1.0371e+10 1.0399e+10  0.27%     -    5s
#      0     0 1.0399e+10    0  224 1.0371e+10 1.0399e+10  0.27%     -    5s
# H    0     0                    1.038312e+10 1.0399e+10  0.16%     -    6s
#      0     0 1.0399e+10    0  230 1.0383e+10 1.0399e+10  0.15%     -    6s
# H    0     0                    1.038441e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  200 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  212 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  223 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  223 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  222 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  250 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  210 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  210 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  199 1.0384e+10 1.0399e+10  0.14%     -    6s
#      0     0 1.0399e+10    0  216 1.0384e+10 1.0399e+10  0.14%     -    7s
#      0     0 1.0399e+10    0  213 1.0384e+10 1.0399e+10  0.14%     -    7s
#      0     0 1.0399e+10    0  191 1.0384e+10 1.0399e+10  0.14%     -    7s
#      0     0 1.0399e+10    0  207 1.0384e+10 1.0399e+10  0.14%     -    7s
#      0     0 1.0398e+10    0  230 1.0384e+10 1.0398e+10  0.14%     -    7s
#      0     0 1.0398e+10    0  231 1.0384e+10 1.0398e+10  0.14%     -    7s
#      0     0 1.0398e+10    0  230 1.0384e+10 1.0398e+10  0.14%     -    7s
#      0     0 1.0398e+10    0  226 1.0384e+10 1.0398e+10  0.14%     -    7s
#      0     0 1.0398e+10    0  247 1.0384e+10 1.0398e+10  0.13%     -    7s
#      0     0 1.0398e+10    0  227 1.0384e+10 1.0398e+10  0.13%     -    7s
#      0     0 1.0398e+10    0  222 1.0384e+10 1.0398e+10  0.13%     -    7s
#      0     0 1.0398e+10    0  198 1.0384e+10 1.0398e+10  0.13%     -    7s
#      0     0 1.0398e+10    0  205 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  223 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  237 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  206 1.0384e+10 1.0398e+10  0.13%     -    8s
# H    0     0                    1.038441e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  221 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  208 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  210 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  207 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  215 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  210 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  219 1.0384e+10 1.0398e+10  0.13%     -    8s
#      0     0 1.0398e+10    0  255 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  267 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  232 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  254 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  252 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  243 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  235 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  234 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  215 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  207 1.0384e+10 1.0398e+10  0.13%     -    9s
#      0     0 1.0398e+10    0  177 1.0384e+10 1.0398e+10  0.13%     -    9s
# H    0     0                    1.038470e+10 1.0398e+10  0.13%     -   10s
#      0     0 1.0398e+10    0  183 1.0385e+10 1.0398e+10  0.13%     -   10s
#      0     0 1.0398e+10    0  191 1.0385e+10 1.0398e+10  0.13%     -   10s
#      0     0 1.0398e+10    0  194 1.0385e+10 1.0398e+10  0.13%     -   10s
#      0     0 1.0398e+10    0  195 1.0385e+10 1.0398e+10  0.13%     -   10s
#      0     0 1.0398e+10    0  206 1.0385e+10 1.0398e+10  0.12%     -   10s
#      0     0 1.0398e+10    0  214 1.0385e+10 1.0398e+10  0.12%     -   10s
#      0     0 1.0398e+10    0  252 1.0385e+10 1.0398e+10  0.12%     -   10s
#      0     0 1.0398e+10    0  221 1.0385e+10 1.0398e+10  0.12%     -   10s
#      0     0 1.0398e+10    0   25 1.0385e+10 1.0398e+10  0.12%     -   11s
#      0     0 1.0398e+10    0   75 1.0385e+10 1.0398e+10  0.12%     -   11s
# H    0     0                    1.038618e+10 1.0398e+10  0.11%     -   11s
#      0     0 1.0398e+10    0  158 1.0386e+10 1.0398e+10  0.11%     -   11s
#      0     0 1.0398e+10    0  214 1.0386e+10 1.0398e+10  0.11%     -   11s
#      0     0 1.0398e+10    0  221 1.0386e+10 1.0398e+10  0.11%     -   12s
#      0     0 1.0398e+10    0  215 1.0386e+10 1.0398e+10  0.11%     -   12s
#      0     0 1.0398e+10    0  214 1.0386e+10 1.0398e+10  0.11%     -   12s
# H    0     0                    1.038777e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  229 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  229 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  232 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  226 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  234 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  233 1.0388e+10 1.0398e+10  0.10%     -   12s
#      0     0 1.0398e+10    0  224 1.0388e+10 1.0398e+10  0.10%     -   12s
# H    0     0                    1.038818e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  251 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  246 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  246 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  222 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  228 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  229 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  241 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  235 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  237 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  217 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  222 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  227 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  214 1.0388e+10 1.0398e+10  0.09%     -   13s
#      0     0 1.0398e+10    0  205 1.0388e+10 1.0398e+10  0.09%     -   14s
#      0     0 1.0398e+10    0  217 1.0388e+10 1.0398e+10  0.09%     -   14s
#      0     0 1.0398e+10    0  212 1.0388e+10 1.0398e+10  0.09%     -   14s
#      0     2 1.0398e+10    0  201 1.0388e+10 1.0398e+10  0.09%     -   14s
# H   31    39                    1.039102e+10 1.0397e+10  0.06%   229   15s
# H  110   135                    1.039224e+10 1.0397e+10  0.05%   146   16s
# H 1033   927                    1.039326e+10 1.0397e+10  0.04%   102   18s
# H 1075   901                    1.039340e+10 1.0397e+10  0.04%   101   18s
# H 1141   795                    1.039426e+10 1.0397e+10  0.03%  98.3   18s
#   1426  1207 1.0396e+10   19  133 1.0394e+10 1.0397e+10  0.03%  95.7   20s
# H 1788  1148                    1.039443e+10 1.0397e+10  0.03%  91.8   21s
# H 1803  1100                    1.039464e+10 1.0397e+10  0.03%  91.0   21s
# H 1841  1069                    1.039503e+10 1.0397e+10  0.02%  89.2   24s
#   1854  1079 1.0396e+10   52  229 1.0395e+10 1.0397e+10  0.02%  96.1   25s
#   1923  1126 1.0396e+10   28  233 1.0395e+10 1.0396e+10  0.01%   100   30s
#   4086  1942 1.0395e+10   55  160 1.0395e+10 1.0396e+10  0.01%  97.1   35s
#
# Cutting planes:
#   Learned: 87
#   Gomory: 13
#   Cover: 27
#   Implied bound: 21
#   Projected implied bound: 4
#   Clique: 6
#   MIR: 271
#   StrongCG: 3
#   Flow cover: 137
#   RLT: 27
#   Relax-and-lift: 18
#
# Explored 4588 nodes (484088 simplex iterations) in 35.84 seconds (32.88 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 1.0395e+10 1.03946e+10 1.03944e+10 ... 1.03878e+10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.039503415648e+10, best bound 1.039604565131e+10, gap 0.0097%

# %%
model.printAttr('X')
# Out:
#     Variable            X
# -------------------------
# R_btck[Machali,dia_16,G,1000]            1
# R_btck[Machali,dia_25,V,3000]            1
# R_btck[Machali,dia_27,CS,1000]            1
# R_btck[Machali,dia_29,Ch,6000]            1
# R_btck[Machali,dia_29,CS,3000]            1
# R_btck[Machali,dia_29,CS,6000]            1
# R_btck[Machali,dia_32,SB,3000]            1
# R_btck[Machali,dia_32,CS,3000]            1
# R_btck[Machali,dia_33,SB,3000]            1
# R_btck[Machali,dia_34,CS,6000]            1
# R_btck[Machali,dia_37,CS,3000]            1
# R_btck[Machali,dia_39,Ch,1000]            1
# R_btck[Machali,dia_39,SB,6000]            1
# R_btck[Machali,dia_41,Ch,1000]            1
# R_btck[Machali,dia_44,SB,3000]            1
# R_btck[Machali,dia_46,M,6000]            1
# R_btck[Machali,dia_47,Ch,3000]            1
# R_btck[Machali,dia_49,CS,6000]            1
# R_btck[Machali,dia_50,C,1000]            1
# R_btck[Machali,dia_54,C,3000]            1
# R_btck[Machali,dia_54,CS,3000]            1
# R_btck[Machali,dia_56,S,1000]            1
# R_btck[Machali,dia_58,SB,6000]            1
# R_btck[Machali,dia_59,CF,3000]            1
# R_btck[Machali,dia_60,S,1000]            1
# R_btck[Machali,dia_64,M,1000]            1
# R_btck[Machali,dia_66,CS,3000]            1
# R_btck[Machali,dia_68,CS,1000]            1
# R_btck[Machali,dia_68,CS,6000]            1
# R_btck[Machali,dia_73,C,3000]            1
# R_btck[Machali,dia_76,C,3000]            1
# R_btck[Chepica,dia_26,CS,1000]            1
# R_btck[Chepica,dia_29,CS,3000]            1
# R_btck[Chepica,dia_34,SB,1000]            1
# R_btck[Chepica,dia_34,SB,3000]            1
# R_btck[Chepica,dia_43,Ch,1000]            1
# R_btck[Chepica,dia_51,CF,1000]            1
# R_btck[Chepica,dia_54,CS,3000]            1
# R_btck[Chepica,dia_60,S,1000]            1
# R_btck[Chepica,dia_63,CS,6000]            1
# R_btck[Chepica,dia_73,C,3000]            1
# R_btck[Nancagua,dia_13,CS,1000]            1
# R_btck[Nancagua,dia_16,CS,3000]            1
# R_btck[Nancagua,dia_17,CS,3000]            1
# R_btck[Nancagua,dia_23,CS,1000]            1
# R_btck[Nancagua,dia_25,Ch,3000]            1
# R_btck[Nancagua,dia_28,CS,1000]            1
# R_btck[Nancagua,dia_29,CS,6000]            1
# R_btck[Nancagua,dia_30,SB,3000]            1
# R_btck[Nancagua,dia_31,CS,3000]            1
# R_btck[Nancagua,dia_34,CS,3000]            1
# R_btck[Nancagua,dia_35,CS,3000]            1
# R_btck[Nancagua,dia_36,S,3000]            1
# R_btck[Nancagua,dia_37,SB,3000]            1
# R_btck[Nancagua,dia_40,CS,1000]            1
# R_btck[Nancagua,dia_41,C,1000]            1
# R_btck[Nancagua,dia_42,C,1000]            1
# R_btck[Nancagua,dia_42,CS,1000]            1
# R_btck[Nancagua,dia_44,Ch,3000]            1
# R_btck[Nancagua,dia_44,C,1000]            1
# R_btck[Nancagua,dia_48,SB,6000]            1
# R_btck[Nancagua,dia_50,SB,3000]            1
# R_btck[Nancagua,dia_50,M,6000]            1
# R_btck[Nancagua,dia_51,M,1000]            1
# R_btck[Nancagua,dia_63,C,3000]            1
# R_btck[Nancagua,dia_69,CS,1000]            1
# R_btck[Nancagua,dia_69,CS,3000]            1
# X_bjt[Machali,cuartel_1,dia_16]         72.2
# X_bjt[Machali,cuartel_2,dia_47]         72.2
# X_bjt[Machali,cuartel_3,dia_39]         72.2
# X_bjt[Machali,cuartel_4,dia_50]         72.2
# X_bjt[Machali,cuartel_5,dia_32]         72.2
# X_bjt[Machali,cuartel_6,dia_29]         72.2
# X_bjt[Machali,cuartel_7,dia_32]       59.375
# X_bjt[Machali,cuartel_7,dia_33]       12.825
# X_bjt[Machali,cuartel_8,dia_68]         72.2
# X_bjt[Machali,cuartel_9,dia_27]      49.9333
# X_bjt[Machali,cuartel_10,dia_56]         72.2
# X_bjt[Machali,cuartel_11,dia_46]         72.2
# X_bjt[Machali,cuartel_12,dia_76]         72.2
# X_bjt[Machali,cuartel_13,dia_66]         72.2
# X_bjt[Machali,cuartel_16,dia_34]         72.2
# X_bjt[Machali,cuartel_17,dia_33]         15.3
# X_bjt[Machali,cuartel_20,dia_29]           25
# X_bjt[Machali,cuartel_22,dia_41]         15.3
# X_bjt[Machali,cuartel_23,dia_37]         72.2
# X_bjt[Machali,cuartel_24,dia_54]         72.2
# X_bjt[Machali,cuartel_25,dia_29]      30.5333
# X_bjt[Machali,cuartel_26,dia_68]         72.2
# X_bjt[Machali,cuartel_27,dia_58]         72.2
# X_bjt[Machali,cuartel_28,dia_49]         72.2
# X_bjt[Machali,cuartel_29,dia_39]       59.375
# X_bjt[Machali,cuartel_29,dia_41]       12.825
# X_bjt[Machali,cuartel_30,dia_59]         72.2
# X_bjt[Machali,cuartel_31,dia_25]         72.2
# X_bjt[Machali,cuartel_32,dia_64]         72.2
# X_bjt[Machali,cuartel_33,dia_44]         72.2
# X_bjt[Machali,cuartel_34,dia_60]           25
# X_bjt[Machali,cuartel_36,dia_73]           25
# X_bjt[Machali,cuartel_37,dia_54]           25
# X_bjt[Chepica,cuartel_9,dia_26]      11.1333
# X_bjt[Chepica,cuartel_17,dia_34]         56.9
# X_bjt[Chepica,cuartel_18,dia_34]         72.2
# X_bjt[Chepica,cuartel_19,dia_26]         72.2
# X_bjt[Chepica,cuartel_20,dia_29]         47.2
# X_bjt[Chepica,cuartel_21,dia_63]         72.2
# X_bjt[Chepica,cuartel_22,dia_43]         56.9
# X_bjt[Chepica,cuartel_34,dia_60]         47.2
# X_bjt[Chepica,cuartel_35,dia_51]         72.2
# X_bjt[Chepica,cuartel_36,dia_73]         47.2
# X_bjt[Chepica,cuartel_37,dia_54]         47.2
# X_bjt[Nancagua,cuartel_9,dia_28]      11.1333
# X_bjt[Nancagua,cuartel_14,dia_34]      19.4222
# X_bjt[Nancagua,cuartel_14,dia_35]      52.7778
# X_bjt[Nancagua,cuartel_15,dia_37]         72.2
# X_bjt[Nancagua,cuartel_25,dia_29]      41.6667
# X_bjt[Nancagua,cuartel_38,dia_16]         72.2
# X_bjt[Nancagua,cuartel_39,dia_51]         72.2
# X_bjt[Nancagua,cuartel_40,dia_31]         72.2
# X_bjt[Nancagua,cuartel_41,dia_44]         72.2
# X_bjt[Nancagua,cuartel_42,dia_40]      19.4222
# X_bjt[Nancagua,cuartel_42,dia_42]      52.7778
# X_bjt[Nancagua,cuartel_43,dia_42]      19.4222
# X_bjt[Nancagua,cuartel_43,dia_44]      52.7778
# X_bjt[Nancagua,cuartel_44,dia_28]         72.2
# X_bjt[Nancagua,cuartel_45,dia_69]         72.2
# X_bjt[Nancagua,cuartel_46,dia_48]         72.2
# X_bjt[Nancagua,cuartel_47,dia_40]         72.2
# X_bjt[Nancagua,cuartel_48,dia_63]         72.2
# X_bjt[Nancagua,cuartel_49,dia_17]         72.2
# X_bjt[Nancagua,cuartel_50,dia_69]         72.2
# X_bjt[Nancagua,cuartel_51,dia_23]         72.2
# X_bjt[Nancagua,cuartel_52,dia_50]         72.2
# X_bjt[Nancagua,cuartel_53,dia_50]         72.2
# X_bjt[Nancagua,cuartel_54,dia_41]      49.9556
# X_bjt[Nancagua,cuartel_54,dia_42]      22.2444
# X_bjt[Nancagua,cuartel_55,dia_13]         72.2
# X_bjt[Nancagua,cuartel_56,dia_25]         72.2
# X_bjt[Nancagua,cuartel_57,dia_34]         72.2
# X_bjt[Nancagua,cuartel_58,dia_36]         72.2
# X_bjt[Nancagua,cuartel_59,dia_48]         72.2
# X_bjt[Nancagua,cuartel_60,dia_30]         72.2
# Y_btcke[Machali,dia_16,G,1000,estanque_machali_3]            1
# Y_btcke[Machali,dia_16,G,1000,estanque_machali_13]            1
# Y_btcke[Machali,dia_25,V,3000,estanque_machali_2]            1
# Y_btcke[Machali,dia_27,CS,1000,estanque_machali_12]            1
# Y_btcke[Machali,dia_29,Ch,6000,estanque_machali_10]            1
# Y_btcke[Machali,dia_29,CS,3000,estanque_machali_9]            1
# Y_btcke[Machali,dia_29,CS,6000,estanque_machali_7]            1
# Y_btcke[Machali,dia_32,SB,3000,estanque_machali_13]            1
# Y_btcke[Machali,dia_32,CS,3000,estanque_machali_11]            1
# Y_btcke[Machali,dia_33,SB,3000,estanque_machali_3]            1
# Y_btcke[Machali,dia_34,CS,6000,estanque_machali_5]            1
# Y_btcke[Machali,dia_37,CS,3000,estanque_machali_2]            1
# Y_btcke[Machali,dia_39,Ch,1000,estanque_machali_12]            1
# Y_btcke[Machali,dia_39,SB,6000,estanque_machali_6]            1
# Y_btcke[Machali,dia_41,Ch,1000,estanque_machali_9]            1
# Y_btcke[Machali,dia_44,SB,3000,estanque_machali_10]            1
# Y_btcke[Machali,dia_46,M,6000,estanque_machali_5]            1
# Y_btcke[Machali,dia_47,Ch,3000,estanque_machali_11]            1
# Y_btcke[Machali,dia_49,CS,6000,estanque_machali_2]            1
# Y_btcke[Machali,dia_50,C,1000,estanque_machali_7]            1
# Y_btcke[Machali,dia_50,C,1000,estanque_machali_13]            1
# Y_btcke[Machali,dia_54,C,3000,estanque_machali_6]            1
# Y_btcke[Machali,dia_54,CS,3000,estanque_machali_9]            1
# Y_btcke[Machali,dia_56,S,1000,estanque_machali_10]            1
# Y_btcke[Machali,dia_58,SB,6000,estanque_machali_5]            1
# Y_btcke[Machali,dia_59,CF,3000,estanque_machali_11]            1
# Y_btcke[Machali,dia_60,S,1000,estanque_machali_3]            1
# Y_btcke[Machali,dia_64,M,1000,estanque_machali_7]            1
# Y_btcke[Machali,dia_64,M,1000,estanque_machali_13]            1
# Y_btcke[Machali,dia_66,CS,3000,estanque_machali_6]            1
# Y_btcke[Machali,dia_68,CS,1000,estanque_machali_10]            1
# Y_btcke[Machali,dia_68,CS,6000,estanque_machali_9]            1
# Y_btcke[Machali,dia_68,CS,6000,estanque_machali_12]            1
# Y_btcke[Machali,dia_73,C,3000,estanque_machali_3]            1
# Y_btcke[Machali,dia_76,C,3000,estanque_machali_2]            1
# Y_btcke[Chepica,dia_26,CS,1000,estanque_chepica_2]            1
# Y_btcke[Chepica,dia_29,CS,3000,estanque_chepica_3]            1
# Y_btcke[Chepica,dia_34,SB,1000,estanque_chepica_1]            1
# Y_btcke[Chepica,dia_34,SB,3000,estanque_chepica_6]            1
# Y_btcke[Chepica,dia_43,Ch,1000,estanque_chepica_3]            1
# Y_btcke[Chepica,dia_51,CF,1000,estanque_chepica_1]            1
# Y_btcke[Chepica,dia_54,CS,3000,estanque_chepica_6]            1
# Y_btcke[Chepica,dia_60,S,1000,estanque_chepica_3]            1
# Y_btcke[Chepica,dia_63,CS,6000,estanque_chepica_1]            1
# Y_btcke[Chepica,dia_73,C,3000,estanque_chepica_3]            1
# Y_btcke[Nancagua,dia_13,CS,1000,estanque_nancagua_1]            1
# Y_btcke[Nancagua,dia_16,CS,3000,estanque_nancagua_7]            1
# Y_btcke[Nancagua,dia_17,CS,3000,estanque_nancagua_8]            1
# Y_btcke[Nancagua,dia_23,CS,1000,estanque_nancagua_2]            1
# Y_btcke[Nancagua,dia_25,Ch,3000,estanque_nancagua_1]            1
# Y_btcke[Nancagua,dia_28,CS,1000,estanque_nancagua_9]            1
# Y_btcke[Nancagua,dia_29,CS,6000,estanque_nancagua_4]            1
# Y_btcke[Nancagua,dia_30,SB,3000,estanque_nancagua_8]            1
# Y_btcke[Nancagua,dia_31,CS,3000,estanque_nancagua_7]            1
# Y_btcke[Nancagua,dia_34,CS,3000,estanque_nancagua_12]            1
# Y_btcke[Nancagua,dia_35,CS,3000,estanque_nancagua_10]            1
# Y_btcke[Nancagua,dia_36,S,3000,estanque_nancagua_2]            1
# Y_btcke[Nancagua,dia_37,SB,3000,estanque_nancagua_1]            1
# Y_btcke[Nancagua,dia_40,CS,1000,estanque_nancagua_9]            1
# Y_btcke[Nancagua,dia_41,C,1000,estanque_nancagua_6]            1
# Y_btcke[Nancagua,dia_42,C,1000,estanque_nancagua_4]            1
# Y_btcke[Nancagua,dia_42,CS,1000,estanque_nancagua_3]            1
# Y_btcke[Nancagua,dia_44,Ch,3000,estanque_nancagua_8]            1
# Y_btcke[Nancagua,dia_44,C,1000,estanque_nancagua_13]            1
# Y_btcke[Nancagua,dia_48,SB,6000,estanque_nancagua_5]            1
# Y_btcke[Nancagua,dia_48,SB,6000,estanque_nancagua_10]            1
# Y_btcke[Nancagua,dia_50,SB,3000,estanque_nancagua_7]            1
# Y_btcke[Nancagua,dia_50,M,6000,estanque_nancagua_1]            1
# Y_btcke[Nancagua,dia_51,M,1000,estanque_nancagua_2]            1
# Y_btcke[Nancagua,dia_63,C,3000,estanque_nancagua_8]            1
# Y_btcke[Nancagua,dia_69,CS,1000,estanque_nancagua_2]            1
# Y_btcke[Nancagua,dia_69,CS,3000,estanque_nancagua_1]            1
# N_jt[cuartel_1,dia_16]        144.4
# N_jt[cuartel_2,dia_47]      171.905
# N_jt[cuartel_3,dia_39]      240.667
# N_jt[cuartel_4,dia_50]        144.4
# N_jt[cuartel_5,dia_32]      171.905
# N_jt[cuartel_6,dia_29]      240.667
# N_jt[cuartel_7,dia_32]      141.369
# N_jt[cuartel_7,dia_33]      30.5357
# N_jt[cuartel_8,dia_68]      240.667
# N_jt[cuartel_9,dia_26]      22.2667
# N_jt[cuartel_9,dia_27]      99.8667
# N_jt[cuartel_9,dia_28]      22.2667
# N_jt[cuartel_10,dia_56]        144.4
# N_jt[cuartel_11,dia_46]      240.667
# N_jt[cuartel_12,dia_76]      171.905
# N_jt[cuartel_13,dia_66]      171.905
# N_jt[cuartel_14,dia_34]      46.2434
# N_jt[cuartel_14,dia_35]      125.661
# N_jt[cuartel_15,dia_37]      171.905
# N_jt[cuartel_16,dia_34]      240.667
# N_jt[cuartel_17,dia_33]      36.4286
# N_jt[cuartel_17,dia_34]      135.476
# N_jt[cuartel_18,dia_34]        144.4
# N_jt[cuartel_19,dia_26]        144.4
# N_jt[cuartel_20,dia_29]      171.905
# N_jt[cuartel_21,dia_63]      240.667
# N_jt[cuartel_22,dia_41]         30.6
# N_jt[cuartel_22,dia_43]        113.8
# N_jt[cuartel_23,dia_37]      171.905
# N_jt[cuartel_24,dia_54]      171.905
# N_jt[cuartel_25,dia_29]      240.667
# N_jt[cuartel_26,dia_68]        144.4
# N_jt[cuartel_27,dia_58]      240.667
# N_jt[cuartel_28,dia_49]      240.667
# N_jt[cuartel_29,dia_39]       118.75
# N_jt[cuartel_29,dia_41]        25.65
# N_jt[cuartel_30,dia_59]      171.905
# N_jt[cuartel_31,dia_25]      171.905
# N_jt[cuartel_32,dia_64]        144.4
# N_jt[cuartel_33,dia_44]      171.905
# N_jt[cuartel_34,dia_60]        144.4
# N_jt[cuartel_35,dia_51]        144.4
# N_jt[cuartel_36,dia_73]      171.905
# N_jt[cuartel_37,dia_54]      171.905
# N_jt[cuartel_38,dia_16]      171.905
# N_jt[cuartel_39,dia_51]        144.4
# N_jt[cuartel_40,dia_31]      171.905
# N_jt[cuartel_41,dia_44]      171.905
# N_jt[cuartel_42,dia_40]      38.8444
# N_jt[cuartel_42,dia_42]      105.556
# N_jt[cuartel_43,dia_42]      38.8444
# N_jt[cuartel_43,dia_44]      105.556
# N_jt[cuartel_44,dia_28]        144.4
# N_jt[cuartel_45,dia_69]      171.905
# N_jt[cuartel_46,dia_48]      240.667
# N_jt[cuartel_47,dia_40]        144.4
# N_jt[cuartel_48,dia_63]      171.905
# N_jt[cuartel_49,dia_17]      171.905
# N_jt[cuartel_50,dia_69]        144.4
# N_jt[cuartel_51,dia_23]        144.4
# N_jt[cuartel_52,dia_50]      240.667
# N_jt[cuartel_53,dia_50]      171.905
# N_jt[cuartel_54,dia_41]      99.9111
# N_jt[cuartel_54,dia_42]      44.4889
# N_jt[cuartel_55,dia_13]        144.4
# N_jt[cuartel_56,dia_25]      171.905
# N_jt[cuartel_57,dia_34]      171.905
# N_jt[cuartel_58,dia_36]      171.905
# N_jt[cuartel_59,dia_48]      240.667
# N_jt[cuartel_60,dia_30]      171.905

# %%
var_names = []
var_bodega = []
var_cuartel = []
var_dia = []
var_values = []
dia_min = []

for var in model.getVars():
    if var.X > 0 and var.varName[0] == 'X':
        splitted_var = var.VarName.split(',')
        splitted_var2 = splitted_var[0].split('[')
        var_names.append(splitted_var2[0])
        var_bodega.append(splitted_var2[1])
        var_cuartel.append(splitted_var[1])
        var_dia.append(splitted_var[2].strip(']'))
        var_values.append(var.x)

# %%
var_values2 = []
for cuartel, valor in zip(var_cuartel, var_values):
    var_values2.append((valor)*conversion[cuartel])

# %%
df_solucion = pd.DataFrame({'Variable': var_names, 'Cuartel': var_cuartel, 'Dia': var_dia, 'Bodega': var_bodega, 'Valor': var_values2})

# %%
open("solucion.csv","w")
df_solucion.to_csv("solucion.csv",index=False, mode="a")

# %%
df_solucion
# Out:
#    Variable     Cuartel     Dia    Bodega  Valor
# 0     X_bjt   cuartel_1  dia_16   Machali  64.98
# 1     X_bjt   cuartel_2  dia_47   Machali  57.76
# 2     X_bjt   cuartel_3  dia_39   Machali  57.76
# 3     X_bjt   cuartel_4  dia_50   Machali  64.98
# 4     X_bjt   cuartel_5  dia_32   Machali  64.98
# ..      ...         ...     ...       ...    ...
# 70    X_bjt  cuartel_56  dia_25  Nancagua  57.76
# 71    X_bjt  cuartel_57  dia_34  Nancagua  64.98
# 72    X_bjt  cuartel_58  dia_36  Nancagua  64.98
# 73    X_bjt  cuartel_59  dia_48  Nancagua  57.76
# 74    X_bjt  cuartel_60  dia_30  Nancagua  57.76
#
# [75 rows x 5 columns]
